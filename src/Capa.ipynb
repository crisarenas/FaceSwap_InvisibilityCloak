# %% [markdown]
# # Capa de la invisibilidad
# * [Github](https://github.com/puranjay123/Invisible-Cloak-openCV-/blob/main/invisible_Cloak.py)
#
#
# * [Web](https://www.analyticsvidhya.com/blog/2021/07/harry-potters-invisible-cloak-using-opencv-python/)

# %%
# Import Libraries
import numpy as np
import cv2
import time

#To use webcam  enter 0 and to enter the video path in dowble quotes
cap = cv2.VideoCapture(0)

time.sleep(3)       # parantheis haas two because the camera needs time to adjust it self i according to the environment(ANDHERA KAMRA)

background = 0


# Capturing the background
for i in range(60):

    ret, background = cap.read()
#capturing image
background = np.flip(background,axis=1)
while(cap.isOpened()):  #Condition for this is when only the web cam is opened  it will only run the code else the code will not run in the background without the webbcam

    ret, img = cap.read()
    if not ret:
        break
    img = np.flip(img,axis=1)
    hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    #HSV values

    #setting the values for the cloak
    lower_red = np.array([130,35,56])
    upper_red = np.array([150,255,255])
#147-167
    mask1 = cv2.inRange(hsv, lower_red,upper_red)

    lower_red = np.array([170,35,56])
    upper_red =  np.array([190,255,255])
    mask2 = cv2.inRange(hsv,lower_red,upper_red)

    mask1 = mask1 +mask2

    mask1 = cv2.morphologyEx(mask1,cv2.MORPH_OPEN,np.ones((3,3),np.uint8), iterations = 2)
    mask1 = cv2.morphologyEx(mask1, cv2.MORPH_DILATE,np.ones((3,3),np.uint8), iterations = 1)

    mask2 =cv2.bitwise_not(mask1)

    res1 = cv2.bitwise_and(background,background,mask=mask1)
    res2 = cv2.bitwise_and(img,img,mask=mask2)
    final_output = cv2.addWeighted(res1,1,res2,1,0)
    cv2.imshow('Invisible Cloak',final_output)
    k = cv2.waitKey(10)
    if k==27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
# Esto funciona bien    
    #setting the values for the cloak
    lower_red = np.array([130,37,56])
    upper_red = np.array([150,255,255])
#147-167
    mask1 = cv2.inRange(hsv, lower_red,upper_red)

    lower_red = np.array([170,37,56])
    upper_red =  np.array([190,255,255])

# %% [markdown]
# # Para buscar capa de color

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
image = cv2.imread("fondo2.jpg")
# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    #imS = cv2.resize(result, (960, 540))  
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 1), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 2), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 3), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 4), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 10), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 18), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 10), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 4), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 147 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 147 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 253, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 251, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 249, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 247, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 246, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 243, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 242, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 241, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 240, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 238, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 237, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 233, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 232, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 240, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 248, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 1), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 2), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 3), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 4), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 8), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 10), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 12), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 14), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 18), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 1), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 68 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 77 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 83 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 84 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 85 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 89 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 91 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 94 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 96 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 99 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 119 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 134 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 136 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 137 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 141 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 168 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 169 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 167 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 166 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 165 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 164 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 163 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 162 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 161 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 160 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 159 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 158 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 157 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 156 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 155 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 154 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 152 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 150 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 148 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 60, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 64, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 70, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 73, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 75, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 79, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 78, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 76, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 74, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 73, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 69, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 66, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 61, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 2), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 9), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 12), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 15), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 21), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 24), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 26), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 27), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 40), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 45), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 49), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 60), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 88), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 89), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 101), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 101), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 89), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 88), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 64), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 88), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 88), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 82), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 81), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 66), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 64), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 62), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 61), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 60), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 252, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 251, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 250, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 249, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 248, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 247, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 246, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 244, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 243, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 242, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 241, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 238, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 237, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 232, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 231, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 229, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 228, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 227, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 225, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 223, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 222, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 220, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 219, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 217, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 216, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 213, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 212, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 211, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 208, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 206, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 204, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 202, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 200, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 196, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 194, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 193, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 192, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 191, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 190, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 189, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 188, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 186, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 184, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 182, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 179, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 175, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 169, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 167, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 161, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 155, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 151, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 150, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 149, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 148, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 146, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 143, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 141, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 133, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 123, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 116, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 96, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 84, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 79, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 70, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 68, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 65, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 62, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 59, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 56, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 54, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 53, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 51, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 50, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 49, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 50, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 52, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 55, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 58, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 64, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 69, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 76, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 86, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 91, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 103, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 117, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 125, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 147, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 158, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 193, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 247, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 251, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 253, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 147 , sMin = 37, vMin = 56), (hMax = 167 , sMax = 255, vMax = 255)

# %% [markdown]
# # Face swap bitch

# %%
# import the necessary packages
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2

# construct the argument parser and parse the arguments
cap = cv2.VideoCapture(0)

while(cap.isOpened()):  #Condition for this is when only the web cam is opened  it will only run the code else the code will not run in the background without the webbcam
    ret, image = cap.read()
    if not ret:
        break

    shape_predictor = "shape_predictor.dat" 
    # initialize dlib's face detector (HOG-based) and then create
    # the facial landmark predictor
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor(shape_predictor)

    # load the input image, resize it, and convert it to grayscale
    image = imutils.resize(image, width=500)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # detect faces in the grayscale image
    rects = detector(gray, 1)

    # loop over the face detections
    for (i, rect) in enumerate(rects):
        # determine the facial landmarks for the face region, then
        # convert the facial landmark (x, y)-coordinates to a NumPy
        # array
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)
        # convert dlib's rectangle to a OpenCV-style bounding box
        # [i.e., (x, y, w, h)], then draw the face bounding box
        (x, y, w, h) = face_utils.rect_to_bb(rect)
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
        # show the face number
        cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        # loop over the (x, y)-coordinates for the facial landmarks
        # and draw them on the image
        for (x, y) in shape:
            cv2.circle(image, (x, y), 1, (0, 0, 255), -1)
# show the output image with the face detections + facial landmarks
cv2.imshow("Output", image)
cv2.waitKey(0)
cap.release()
cv2.destroyAllWindows()

# %%
dde
de
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82c0fa4f4d1d> in <module>
# ----> 1 dde
#       2 de
#
# NameError: name 'dde' is not defined
